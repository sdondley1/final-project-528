# %%
import os 
import pandas as pd

down  = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\down'
up =  'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\up'
left =  'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\left'
right =  'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\right'
still = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\still'
round = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\round'
turn = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\turn'

dataframes_down = {}
dataframes_up = {}
dataframes_left= {}
dataframes_right = {}
dataframes_still = {}
dataframes_round = {}
dataframes_turn = {}

for filename in os.listdir(down):
    if filename.endswith('.csv'):
        file = os.path.join(down, filename)
        df=pd.read_csv(file)
        dataframes_down[filename] = df

for filename in os.listdir(up):
    if filename.endswith('.csv'):
        file = os.path.join(up, filename)
        df=pd.read_csv(file)
        dataframes_up[filename] = df

for filename in os.listdir(left):
    if filename.endswith('.csv'):
        file = os.path.join(left, filename)
        df=pd.read_csv(file)
        dataframes_left[filename] = df

for filename in os.listdir(right):
    if filename.endswith('.csv'):
        file = os.path.join(right, filename)
        df=pd.read_csv(file)
        dataframes_right[filename] = df

for filename in os.listdir(still):
    if filename.endswith('.csv'):
        file = os.path.join(still, filename)
        df=pd.read_csv(file)
        dataframes_still[filename] = df

for filename in os.listdir(round):
    if filename.endswith('.csv'):
        file=os.path.join(round, filename)
        df=pd.read_csv(file)
        dataframes_round[filename] = df

for filename in os.listdir(turn):
    if filename.endswith('.csv'):
        file=os.path.join(turn, filename)
        df=pd.read_csv(file)
        dataframes_turn[filename] = df

print(len(dataframes_down))
print(len(dataframes_up))
print(len(dataframes_left))
print(len(dataframes_right))
print(len(dataframes_still))
print(len(dataframes_round))
print(len(dataframes_turn))
# Out:
# C:\Users\Sahil.DESKTOP-V0F9A4D\AppData\Local\Temp\ipykernel_23496\3840553791.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 20
# 20
# 20
# 20
# 20
# 20
# 20

# %%
import numpy as np 
import matplotlib.pyplot as plt

down1= dataframes_down['down15.csv']

fft_x = np.fft.fft(down1['acce_x'])
fft_y = np.fft.fft(down1['acce_y'])
fft_z = np.fft.fft(down1['acce_z'])

sampling_rate = 400
n=len(down1)
frequency = np.fft.fftfreq(n, d=1/sampling_rate)

fft_dataframe_down = pd.DataFrame({
    'frequency': frequency,
    'fft_x': np.abs(fft_x),
    'fft_y': np.abs(fft_y),
    'fft_z': np.abs(fft_z)
})

plt.figure(figsize=(15,15))

plt.subplot(3,1,1)
plt.plot( fft_dataframe_down['fft_x'], label='fft_x',color='black')
plt.plot( fft_dataframe_down['fft_y'], label='fft_y', color='red')
plt.plot( fft_dataframe_down['fft_z'], label='fft_z', color='green')
plt.title('FFT of Accelerometer Data (acce_x, acce_y, acce_z)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.xlim(0, sampling_rate / 2)
plt.xticks(np.arange(0, 200, 5))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# This FFT Data of the down gesture seems to indicate majority of the frequency change sticks to the z axis, which is what we would expect in a downwards motion sinze Z is the primary axis affected

# %%
down1= dataframes_down['down15.csv']

fft_x = np.fft.fft(down1['gyro_x'])
fft_y = np.fft.fft(down1['gyro_y'])
fft_z = np.fft.fft(down1['gyro_z'])

sampling_rate = 400
n=len(down1)
frequency = np.fft.fftfreq(n, d=1/sampling_rate)

fft_dataframe_down = pd.DataFrame({
    'frequency': frequency,
    'fft_x': np.abs(fft_x),
    'fft_y': np.abs(fft_y),
    'fft_z': np.abs(fft_z)
})

plt.figure(figsize=(15,15))

plt.subplot(3,1,1)
plt.plot( fft_dataframe_down['fft_x'], label='fft_x',color='black')
plt.plot( fft_dataframe_down['fft_y'], label='fft_y', color='red')
plt.plot( fft_dataframe_down['fft_z'], label='fft_z', color='green')
plt.title('FFT of Gyro Data (gyro_x, gyro_y, gyro_z)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.xlim(0, sampling_rate / 2)
plt.xticks(np.arange(0, 200, 5))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Yeah I have no idea what is happening here. It seems the gyro data fluctates massively, and major fluctations are recorded in the x axis, as well as some variation in the z axis, which is expected in a downwards motion

# %%
up1= dataframes_up['up8.csv']

fft_x = np.fft.fft(up1['acce_x'])
fft_y = np.fft.fft(up1['acce_y'])
fft_z = np.fft.fft(up1['acce_z'])

sampling_rate = 400
n=len(up1)
frequency = np.fft.fftfreq(n, d=1/sampling_rate)

fft_dataframe_up = pd.DataFrame({
    'frequency': frequency,
    'fft_x': np.abs(fft_x),
    'fft_y': np.abs(fft_y),
    'fft_z': np.abs(fft_z)
})

plt.figure(figsize=(15,15))

plt.subplot(3,1,1)
plt.plot( fft_dataframe_up['fft_x'], label='fft_x',color='black')
plt.plot( fft_dataframe_up['fft_y'], label='fft_y', color='red')
plt.plot( fft_dataframe_up['fft_z'], label='fft_z', color='green')
plt.title('FFT of Accelerometer Data (acce_x, acce_y, acce_z)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.xlim(0, sampling_rate / 2)
plt.xticks(np.arange(0, 200, 5))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# As expected, the FFT for the upwards gesture has majority variation in the z axis, as expected. This is just one gesture out of 20, and so it looking somewhat similar to the down gesture is plausible to happen, especially since both affect the same axis primarily. To distinguish these, I think that the acceleration data might be more useful, since there would be more variation in the raw data.

# %%
up1= dataframes_up['up8.csv']

fft_x = np.fft.fft(up1['gyro_x'])
fft_y = np.fft.fft(up1['gyro_y'])
fft_z = np.fft.fft(up1['gyro_z'])

sampling_rate = 400
n=len(up1)
frequency = np.fft.fftfreq(n, d=1/sampling_rate)

fft_dataframe_up = pd.DataFrame({
    'frequency': frequency,
    'fft_x': np.abs(fft_x),
    'fft_y': np.abs(fft_y),
    'fft_z': np.abs(fft_z)
})

plt.figure(figsize=(15,15))

plt.subplot(3,1,1)
plt.plot( fft_dataframe_up['fft_x'], label='fft_x',color='black')
plt.plot( fft_dataframe_up['fft_y'], label='fft_y', color='red')
plt.plot( fft_dataframe_up['fft_z'], label='fft_z', color='green')
plt.title('FFT of Gyro Data (acce_x, acce_y, acce_z)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.xlim(0, sampling_rate / 2)
plt.xticks(np.arange(0, 200, 5))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Yet again, the gyro data fluctuates massively, and major fluctations are recorded in the x axis, as well as now some more variation in the y axis. Near the end of the graph, only the z axis fluctuates

# %%
from scipy.signal import spectrogram
figure, axis = plt.subplots(3,1, figsize=(15,15))


f,t,specX = spectrogram(down1['acce_x'], fs=sampling_rate, nperseg=15)
axis[0].pcolormesh(t,f,specX, shading='gouraud') 

f2,t2,specY = spectrogram(down1['acce_y'], fs=sampling_rate, nperseg=15)
axis[1].pcolormesh(t2,f2,specY, shading='gouraud') 

f3,t3,specZ = spectrogram(down1['acce_z'], fs=sampling_rate, nperseg=15)
axis[2].pcolormesh(t3,f3,specZ, shading='gouraud') 

plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
figure, axis = plt.subplots(3,1, figsize=(15,15))


f,t,specX = spectrogram(down1['gyro_x'], fs=sampling_rate, nperseg=25)
axis[0].pcolormesh(t,f,specX, shading='gouraud') 

f2,t2,specY = spectrogram(down1['gyro_y'], fs=sampling_rate, nperseg=25)
axis[1].pcolormesh(t2,f2,specY, shading='gouraud') 

f3,t3,specZ = spectrogram(down1['gyro_z'], fs=sampling_rate, nperseg=25)
axis[2].pcolormesh(t3,f3,specZ, shading='gouraud') 

plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
figure, axis = plt.subplots(3,1, figsize=(15,15))


f,t,specX = spectrogram(up1['acce_x'], fs=sampling_rate, nperseg=25) #64, 32 should be best
axis[0].pcolormesh(t,f,specX, shading='gouraud') 

f2,t2,specY = spectrogram(up1['acce_y'], fs=sampling_rate, nperseg=25)
axis[1].pcolormesh(t2,f2,specY, shading='gouraud') 

f3,t3,specZ = spectrogram(up1['acce_z'], fs=sampling_rate, nperseg=25)
axis[2].pcolormesh(t3,f3,specZ, shading='gouraud') 

plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
figure, axis = plt.subplots(3,1, figsize=(15,15))


f,t,specX = spectrogram(up1['gyro_x'], fs=sampling_rate, nperseg=25)
axis[0].pcolormesh(t,f,specX, shading='gouraud') 

f2,t2,specY = spectrogram(up1['gyro_y'], fs=sampling_rate, nperseg=25)
axis[1].pcolormesh(t2,f2,specY, shading='gouraud') 

f3,t3,specZ = spectrogram(up1['gyro_z'], fs=sampling_rate, nperseg=25)
axis[2].pcolormesh(t3,f3,specZ, shading='gouraud') 

plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %% [markdown]
# ML MODEL TRAINED WITH RAW DATA

# %%
import os
import seaborn as sns
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
dataframes = [dataframes_down, dataframes_up, dataframes_left,dataframes_right,dataframes_still,dataframes_round,dataframes_turn]
all_data = []
labels = []

label_mapping ={
    'dataframes_down': 0, 'dataframes_up': 1, 'dataframes_left': 2, 'dataframes_right': 3, 'dataframes_still':4, 'dataframes_round':5,'dataframes_turn':6
}

for position, list in enumerate(dataframes):
    for file, frame in list.items():
        all_data.append(frame.values.flatten())
        labels.append(position)

all_data_df = pd.DataFrame(all_data)
labels_series = pd.Series(labels)

# %% [markdown]
# SVM WITH MY RAW DATA

# %%
x_train, x_test, y_train, y_test = train_test_split(all_data_df, labels_series, test_size=0.3, random_state=42)
model = SVC(kernel='rbf')
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap="Blues")
plt.title('train')
plt.xlabel('pred')
plt.ylabel('actual')
plt.show()
# Out:
# 0.8571428571428571

# %% [markdown]
# KNN WITH MY RAW DATA

# %%
# knn_classifier = KNeighborsClassifier(n_neighbors=5)
# knn_classifier.fit(x_train, y_train)
# y_pred=knn_classifier.predict(x_test)
# accuracy = accuracy_score(y_test, y_pred)
# print(accuracy)

# %% [markdown]
# LOADING IN SEAN RAW DATA

# %%
down_sean  = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Archive (3)\\down\\csv2'
up_sean =  'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Archive (3)\\up\\csv2'
left_sean =  'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Archive (3)\\left\\csv2'
right_sean =  'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Archive (3)\\right\\csv2'
still_sean = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Archive (3)\\neutral\\csv2'
round_sean = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Archive (3)\\roll\\csv2'
turn_sean = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Archive (3)\\turn\\csv2'

dataframes_down_sean = {}
dataframes_up_sean = {}
dataframes_left_sean= {}
dataframes_right_sean = {}
dataframes_still_sean = {}
dataframes_round_sean = {}
dataframes_turn_sean ={}

for filename in os.listdir(down_sean):
    if filename.endswith('.csv'):
        file = os.path.join(down_sean, filename)
        df=pd.read_csv(file)
        dataframes_down_sean[filename] = df

for filename in os.listdir(up_sean):
    if filename.endswith('.csv'):
        file = os.path.join(up_sean, filename)
        df=pd.read_csv(file)
        dataframes_up_sean[filename] = df

for filename in os.listdir(left_sean):
    if filename.endswith('.csv'):
        file = os.path.join(left_sean, filename)
        df=pd.read_csv(file)
        dataframes_left_sean[filename] = df

for filename in os.listdir(right_sean):
    if filename.endswith('.csv'):
        file = os.path.join(right_sean, filename)
        df=pd.read_csv(file)
        dataframes_right_sean[filename] = df

for filename in os.listdir(still_sean):
    if filename.endswith('.csv'):
        file = os.path.join(still_sean, filename)
        df=pd.read_csv(file)
        dataframes_still_sean[filename] = df

for filename in os.listdir(round_sean):
    if filename.endswith('.csv'):
        file = os.path.join(round_sean, filename)
        df=pd.read_csv(file)
        dataframes_round_sean[filename] = df

for filename in os.listdir(turn_sean):
    if filename.endswith('.csv'):
        file = os.path.join(turn_sean, filename)
        df=pd.read_csv(file)
        dataframes_turn_sean[filename] = df

dataframes_sean = [dataframes_down_sean, dataframes_up_sean, dataframes_left_sean, dataframes_right_sean, dataframes_still_sean, dataframes_round_sean, dataframes_turn_sean]

print(len(dataframes_sean[0]))
print(len(dataframes_sean[1]))
print(len(dataframes_sean[2]))
print(len(dataframes_sean[3]))
print(len(dataframes_sean[4]))
print(len(dataframes_sean[5]))
print(len(dataframes_sean[6]))
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20

# %%
down_adam = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Movements\\Down'
flip_adam = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Movements\\Flip'
left_adam = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Movements\\Left'
still_adam = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Movements\\Neutral'
right_adam = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Movements\\Right'
turn_adam = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Movements\\Rotate'
up_adam = 'C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\Movements\\Up'


dataframes_down_adam = {}
dataframes_up_adam = {}
dataframes_left_adam= {}
dataframes_right_adam = {}
dataframes_still_adam = {}
dataframes_flip_adam = {}
dataframes_turn_adam ={}

for filename in os.listdir(down_adam):
    if filename.endswith('.csv'):
        file = os.path.join(down_adam, filename)
        df=pd.read_csv(file)
        dataframes_down_adam[filename] = df

for filename in os.listdir(up_adam):
    if filename.endswith('.csv'):
        file = os.path.join(up_adam, filename)
        df=pd.read_csv(file)
        dataframes_up_adam[filename] = df

for filename in os.listdir(left_adam):
    if filename.endswith('.csv'):
        file = os.path.join(left_adam, filename)
        df=pd.read_csv(file)
        dataframes_left_adam[filename] = df

for filename in os.listdir(right_adam):
    if filename.endswith('.csv'):
        file = os.path.join(right_adam, filename)
        df=pd.read_csv(file)
        dataframes_right_adam[filename] = df

for filename in os.listdir(still_adam):
    if filename.endswith('.csv'):
        file = os.path.join(still_adam, filename)
        df=pd.read_csv(file)
        dataframes_still_adam[filename] = df

for filename in os.listdir(flip_adam):
    if filename.endswith('.csv'):
        file = os.path.join(flip_adam, filename)
        df=pd.read_csv(file)
        dataframes_flip_adam[filename] = df

for filename in os.listdir(turn_adam):
    if filename.endswith('.csv'):
        file = os.path.join(turn_adam, filename)
        df=pd.read_csv(file)
        dataframes_turn_adam[filename] = df

dataframes_adam = [dataframes_down_adam, dataframes_up_adam, dataframes_left_adam, dataframes_right_adam, dataframes_still_adam, dataframes_flip_adam, dataframes_turn_adam]
print(len(dataframes_adam[0]))
print(len(dataframes_adam[1]))
print(len(dataframes_adam[2]))
print(len(dataframes_adam[3]))
print(len(dataframes_adam[4]))
print(len(dataframes_adam[5]))
print(len(dataframes_adam[6]))
# Out:
# 20
# 19
# 20
# 20
# 20
# 20
# 20

# %% [markdown]
# SVM COMBINED

# %%
data_combined = []
lables_combined = []

label_mapping ={
    'dataframes_down_sean': 0, 'dataframes_down':0, 'dataframes_down_adam':0, 
    'dataframes_up_sean': 1,'dataframes_up': 1, 'dataframes_up_adam': 1, 
    'dataframes_left_sean': 2, 'dataframes_left':2, 'dataframes_left_adam': 2, 
    'dataframes_right_sean': 3, 'dataframes_right': 3, 'dataframes_right_adam': 3, 
    'dataframes_still_sean': 4, 'dataframes_still': 4, 'dataframes_still_adam': 4,
    'dataframes_round_sean': 5, 'dataframes_round': 5, 'dataframes_flip_adam': 5,
    'dataframes_turn_sean': 6, 'dataframes_turn': 6, 'dataframes_turn_adam': 6,
}

for position, list in enumerate(dataframes_sean):
    for file, frame in list.items():
        data_combined.append(frame.values.flatten())
        lables_combined.append(position)

for position, list in enumerate(dataframes):
    for file, frame in list.items():
        data_combined.append(frame.values.flatten())
        lables_combined.append(position)

for position, list in enumerate(dataframes_adam):
    for file, frame in list.items():
        data_combined.append(frame.values.flatten())
        lables_combined.append(position)

all_data_df_combined = pd.DataFrame(data_combined)
labels_series_combined = pd.Series(lables_combined)

# %%
import numpy as np
high_len = max(len(arr) for arr in data_combined)
data_combined = np.array([np.pad(arr,(0,high_len-len(arr))) for arr in data_combined])
all_data_df_combined = pd.DataFrame(data_combined)

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score


x_train, x_test, y_train, y_test = train_test_split(all_data_df_combined, labels_series_combined, stratify=labels_series_combined, test_size=0.3, random_state=9)
model = SVC(kernel='rbf')
model.fit(x_train, y_train)
y_pred = model.predict(x_test)


accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
print(classification_report(y_test, y_pred))



conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap="Blues")



plt.title('train')
plt.xlabel('pred')
plt.ylabel('actual')
plt.show()
# Out:
# 0.9603174603174603
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        18
#            1       0.94      0.89      0.91        18
#            2       0.95      1.00      0.97        18
#            3       0.95      1.00      0.97        18
#            4       0.95      1.00      0.97        18
#            5       1.00      0.94      0.97        18
#            6       0.94      0.94      0.94        18
#
#     accuracy                           0.96       126
#    macro avg       0.96      0.96      0.96       126
# weighted avg       0.96      0.96      0.96       126

# %% [markdown]
# CHECKING AND WORKING TO SOLVE OVERFITTING

# %%
train_accuracy = model.score(x_train, y_train)
test_accuracy = model.score(x_test, y_test)

print(train_accuracy, test_accuracy)
# Out:
# 0.9965870307167235 0.9603174603174603

# %%
from sklearn.model_selection import cross_val_score
cross_val_scores = cross_val_score(model,x_train, y_train, cv=5)
print(cross_val_scores)
print(cross_val_scores.mean())
# Out:
# [0.94915254 0.88135593 0.91525424 0.89655172 0.94827586]
# 0.9181180596142606

# %%
from sklearn.model_selection import GridSearchCV

parameter_range = {'C': [0.01, 0.1, 1, 10, 100], 'gamma': ['scale', 0.001,0.01,0.1,1,10]}
new_grid = GridSearchCV(SVC(kernel='rbf'), parameter_range, cv=5)
new_grid.fit(x_train, y_train)
print(new_grid.best_params_)
new_model = new_grid.best_estimator_
# Out:
# {'C': 10, 'gamma': 'scale'}

# %% [markdown]
# AFTER HYPERPARAMETER TUNING

# %%
cross_val_scores = cross_val_score(new_model,x_train, y_train, cv=5)
print(cross_val_scores)
print(cross_val_scores.mean())
# Out:
# [0.94915254 0.88135593 0.91525424 0.9137931  1.        ]
# 0.9319111630625365

# %%
train = new_model.score(x_train, y_train)
test = new_model.score(x_test, y_test)
print(train, test)
# Out:
# 1.0 0.9603174603174603

# %%
y_pred = new_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap="Blues")

plt.title('train')
plt.xlabel('pred')
plt.ylabel('actual')
plt.show()
# Out:
# 0.9603174603174603
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        18
#            1       0.94      0.89      0.91        18
#            2       0.95      1.00      0.97        18
#            3       0.95      1.00      0.97        18
#            4       0.95      1.00      0.97        18
#            5       1.00      0.94      0.97        18
#            6       0.94      0.94      0.94        18
#
#     accuracy                           0.96       126
#    macro avg       0.96      0.96      0.96       126
# weighted avg       0.96      0.96      0.96       126

# %% [markdown]
# SCALING APPLIED TO DATA BEFORE SVM

# %%
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()

x_train_standard = scale.fit_transform(x_train)
x_test_standard = scale.transform(x_test)

# %%
parameter_range = {'C': [0.01, 0.1, 1, 10, 100], 'gamma': ['scale', 0.001,0.01,0.1,1,10]}
new_grid_standard = GridSearchCV(SVC(kernel='rbf'), parameter_range, cv=5)
new_grid_standard.fit(x_train_standard, y_train)
print(new_grid_standard.best_params_)
new_model_standard = new_grid_standard.best_estimator_
# Out:
# {'C': 10, 'gamma': 'scale'}

# %%
train_accuracy = new_model_standard.score(x_train_standard, y_train)
test_accuracy = new_model_standard.score(x_test_standard, y_test)
print(train_accuracy, test_accuracy)
# Out:
# 1.0 0.9682539682539683

# %%
y_pred = new_model_standard.predict(x_test_standard)

accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap="Blues")

plt.title('train')
plt.xlabel('pred')
plt.ylabel('actual')
plt.show()
# Out:
# 0.9682539682539683
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        18
#            1       1.00      0.94      0.97        18
#            2       0.90      1.00      0.95        18
#            3       0.95      1.00      0.97        18
#            4       1.00      1.00      1.00        18
#            5       1.00      0.94      0.97        18
#            6       0.94      0.94      0.94        18
#
#     accuracy                           0.97       126
#    macro avg       0.97      0.97      0.97       126
# weighted avg       0.97      0.97      0.97       126

# %%
cross_val_scores = cross_val_score(new_model_standard, x_train_standard, y_train, cv=5)
print(cross_val_scores)
print(cross_val_scores.mean())
# Out:
# [0.98305085 0.89830508 0.98305085 0.94827586 0.94827586]
# 0.9521917007597895

# %% [markdown]
# MANUAL SVM CREATION WITH CUSTOM PARAMETERS

# %%
# model = SVC(kernel='rbf')
# model.fit(x_train, y_train)
# y_pred = model.predict(x_test)


new_model_3 = SVC(kernel='rbf', C=0.75, gamma='scale')
new_model_3.fit(x_train_standard, y_train)
y_pred_new = new_model_3.predict(x_test_standard)

# accuracy = accuracy_score(y_test, y_pred)
# print(accuracy)
# print(classification_report(y_test, y_pred))

accuracy_new = accuracy_score(y_test, y_pred_new)
print(accuracy_new)
print(classification_report(y_test, y_pred_new))


# conf_matrix = confusion_matrix(y_test, y_pred)
# sns.heatmap(conf_matrix, annot=True, cmap="Blues")

conf_matrix_new = confusion_matrix(y_test, y_pred_new)
sns.heatmap(conf_matrix_new, annot=True, cmap="Blues")

# plt.title('train')
# plt.xlabel('pred')
# plt.ylabel('actual')
# plt.show()

plt.title('train')
plt.xlabel('pred')
plt.ylabel('actual')
plt.show()
# Out:
# 0.9365079365079365
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        18
#            1       0.94      0.94      0.94        18
#            2       0.89      0.94      0.92        18
#            3       0.89      0.94      0.92        18
#            4       0.94      0.94      0.94        18
#            5       0.94      0.94      0.94        18
#            6       0.94      0.89      0.91        18
#
#     accuracy                           0.94       126
#    macro avg       0.94      0.94      0.94       126
# weighted avg       0.94      0.94      0.94       126

# %%
train_accuracy_3 = new_model_3.score(x_train_standard, y_train)
test_accuracy_3 = new_model_3.score(x_test_standard, y_test)
print(train_accuracy_3, test_accuracy_3)
# Out:
# 0.9897610921501706 0.9365079365079365

# %%
cross_val_scores_3 = cross_val_score(new_model_3, x_train_standard, y_train, cv=5)
print(cross_val_scores_3)
print(cross_val_scores_3.mean())
# Out:
# [0.98305085 0.86440678 0.91525424 0.86206897 0.9137931 ]
# 0.9077147866744593

# %%
import pickle
with open('gesture_classification_model.pkl', 'wb') as f:
    pickle.dump(new_model_standard, f)

# %%
# Load the fresh data from CSV
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib

model_path = "gesture_classification_model.pkl"

new_file_path = "C:\\Users\\Sahil.DESKTOP-V0F9A4D\\Desktop\\528\\proj_data\\test_data\\test1_left.csv"

model = joblib.load(model_path)

new_data = pd.read_csv(new_file_path)

high_len = 401
new_data_padded = np.pad(new_data.to_numpy(), ((0, high_len - len(new_data)), (0, 0)), mode='constant')

new_data_flat = new_data_padded.reshape(1, -1)


new_data_scaled = scale.fit_transform(new_data_flat)

predicted_label = model.predict(new_data_scaled)

print(f"Predicted Movement: ", predicted_label)
# Out:
# Predicted Movement:  [5]
